# %%
from DataIO import csvToDf
# Out:
# /Users/hadoop1/anaconda/lib/python2.7/site-packages/pandas/computation/__init__.py:19: UserWarning: The installed version of numexpr 2.4.4 is not supported in pandas and will be not be used
#
#   UserWarning)

# %%
dfList = csvToDf('./dropAll/')

# %%
dfList[3][0]
# Out:
#                  SN  Distance_X_LOGO_Camera_RU1  Distance_X_LOGO_Camera_RU2  \
# 0  FLQS11MXGRWQ____                      -0.202                      -0.131
# 1  FLQS11WBGRWQ____                       0.224                       0.238
# 2  FLQS11X1GRWQ____                       0.211                       0.281
# 3  FLQS13MEGRWQ____                      -0.008                      -0.043
# 4  FLQS138GGRWQ____                      -0.125                      -0.124
#
#    Distance_X_LOGO_3  Distance_X_LOGO_4  Distance_X_LOGO_5  Distance_X_LOGO_6  \
# 0             -0.201             -0.201             -0.201             -0.201
# 1              0.242              0.236              0.237              0.236
# 2              0.281              0.281              0.211              0.211
# 3             -0.015             -0.007             -0.008             -0.012
# 4             -0.127             -0.126             -0.123             -0.125
#
# ...

# %%
dfList[0][0]
# Out:
#                  SN  Distance_X_LOGO_Battery_Left1  \
# 0  FLQS11MXGRWQ____                         -0.251
# 1  FLQS11WBGRWQ____                          0.940
# 2  FLQS11X1GRWQ____                          0.011
# 3  FLQS13MEGRWQ____                         -0.551
# 4  FLQS138GGRWQ____                         -0.340
# 5               NaN                            NaN
#
#    Distance_X_LOGO_Battery_Left2  Distance_X_LOGO_Battery_Left3  \
# 0                         -0.314                         -0.308
# 1                          0.940                          0.940
# 2                          0.327                         -0.060
# 3                         -0.306                         -0.383
# 4                         -0.381                         -0.091
# 5                            NaN                            NaN
#
#    Distance_X_LOGO_4  Distance_X_LOGO_5  Distance_X_LOGO_6  Distance_X_LOGO_7  \
# ...
