# %%
import pandas as pd
# Out:
# /Users/hadoop1/anaconda/lib/python2.7/site-packages/pandas/computation/__init__.py:19: UserWarning: The installed version of numexpr 2.4.4 is not supported in pandas and will be not be used
#
#   UserWarning)

# %%
pd.read_excel('file://localhost/Users/hadoop1/projects/SUR-Project/drop/outbount_N66_LD_Camera_RU.xls')
# Out:
# ---------------------------------------------------------------------------
# XLRDError                                 Traceback (most recent call last)
# <ipython-input-7-c6765cd226da> in <module>()
# ----> 1 pd.read_excel('file://localhost/Users/hadoop1/projects/SUR-Project/drop/outbount_N66_LD_Camera_RU.xls')
#
# /Users/hadoop1/anaconda/lib/python2.7/site-packages/pandas/io/excel.pyc in read_excel(io, sheetname, header, skiprows, skip_footer, index_col, names, parse_cols, parse_dates, date_parser, na_values, thousands, convert_float, has_index_names, converters, engine, squeeze, **kwds)
#     167     """
#     168     if not isinstance(io, ExcelFile):
# --> 169         io = ExcelFile(io, engine=engine)
#     170
#     171     return io._parse_excel(
#
# /Users/hadoop1/anaconda/lib/python2.7/site-packages/pandas/io/excel.pyc in __init__(self, io, **kwds)
#     214             elif _is_url(io):
#     215                 data = _urlopen(io).read()
# ...

# %%
pd.ExcelFile("drop/outbount_N66_LD_Camera_RU.xls")
# Out:
# ---------------------------------------------------------------------------
# XLRDError                                 Traceback (most recent call last)
# <ipython-input-8-d26e17e9eccb> in <module>()
# ----> 1 pd.ExcelFile("drop/outbount_N66_LD_Camera_RU.xls")
#
# /Users/hadoop1/anaconda/lib/python2.7/site-packages/pandas/io/excel.pyc in __init__(self, io, **kwds)
#     216                 self.book = xlrd.open_workbook(file_contents=data)
#     217             else:
# --> 218                 self.book = xlrd.open_workbook(io)
#     219         elif engine == 'xlrd' and isinstance(io, xlrd.Book):
#     220             self.book = io
#
# /Users/hadoop1/anaconda/lib/python2.7/site-packages/xlrd/__init__.pyc in open_workbook(filename, logfile, verbosity, use_mmap, file_contents, encoding_override, formatting_info, on_demand, ragged_rows)
#     433         formatting_info=formatting_info,
#     434         on_demand=on_demand,
# --> 435         ragged_rows=ragged_rows,
# ...

# %%
test = pd.ExcelFile("0426model.xlsx")

# %%
test

# %%
df = test.parse("Sheet2")

# %%
df
# Out:
#          date  confidence  TP  FP     TN   FN  precision    recall  \
# 0  2016-05-03          95  30  82  40929  409   0.267857  0.068337
# 1  2016-05-03          96  12  38  40973  427   0.240000  0.027335
# 2  2016-05-03          97   2  13  40998  437   0.133333  0.004556
# 3  2016-05-03          98   1   2  41009  438   0.333333  0.002278
# 4  2016-05-04          95  36  79  58934  582   0.313043  0.058252
# 5  2016-05-04          96  17  41  58972  601   0.293103  0.027508
# 6  2016-05-04          97   7  14  58999  611   0.333333  0.011327
# 7  2016-05-04          98   3   4  59009  615   0.428571  0.004854
# 8  2016-05-05          95  42  82  64974  571   0.338710  0.068515
# 9  2016-05-05          96  24  45  65011  589   0.347826  0.039152
# 10 2016-05-05          97  12  21  65035  601   0.363636  0.019576
# 11 2016-05-05          98   6   0  65056  607   1.000000  0.009788
# 12 2016-05-06          95  26  65  58991  578   0.285714  0.043046
# ...

# %%
test = pd.ExcelFile("outbount_N66_LD_Camera_RU.xls")
# Out:
# ---------------------------------------------------------------------------
# XLRDError                                 Traceback (most recent call last)
# <ipython-input-16-42e01b486bdf> in <module>()
# ----> 1 test = pd.ExcelFile("outbount_N66_LD_Camera_RU.xls")
#
# /Users/hadoop1/anaconda/lib/python2.7/site-packages/pandas/io/excel.pyc in __init__(self, io, **kwds)
#     216                 self.book = xlrd.open_workbook(file_contents=data)
#     217             else:
# --> 218                 self.book = xlrd.open_workbook(io)
#     219         elif engine == 'xlrd' and isinstance(io, xlrd.Book):
#     220             self.book = io
#
# /Users/hadoop1/anaconda/lib/python2.7/site-packages/xlrd/__init__.pyc in open_workbook(filename, logfile, verbosity, use_mmap, file_contents, encoding_override, formatting_info, on_demand, ragged_rows)
#     433         formatting_info=formatting_info,
#     434         on_demand=on_demand,
# --> 435         ragged_rows=ragged_rows,
# ...

# %%
pd.read_csv('outbount_N66_LD_Camera_RU.csv', sep=';')
# Out:
#                  SN  Distance_X_LOGO_Camera_RU1  Distance_X_LOGO_Camera_RU2  \
# 0  FLQS11MXGRWQ____                     -63.561                     -63.280
# 1  FLQS11WBGRWQ____                     -63.216                     -62.924
# 2  FLQS11X1GRWQ____                     -63.292                     -63.012
# 3  FLQS13MEGRWQ____                     -63.615                     -63.339
# 4  FLQS138GGRWQ____                     -63.711                     -63.426
#
#    Distance_X_LOGO_3  Distance_X_LOGO_4  Distance_X_LOGO_5  Distance_X_LOGO_6  \
# 0            -63.350            -63.175            -63.175            -63.210
# 1            -62.991            -62.820            -62.820            -62.855
# 2            -63.012            -62.837            -62.907            -62.942
# 3            -63.410            -63.226            -63.229            -63.270
# 4            -63.498            -63.321            -63.320            -63.359
#
# ...

# %%
pd.read_csv('客退对比N66_LD_Camera_RU.csv', sep=';')
# Out:
#                  SN  Distance_X_LOGO_Camera_RU1  Distance_X_LOGO_Camera_RU2  \
# 0  FLQS20U5GRX2____                      -0.036                      -0.031
# 1  FLQS21TBGRWM____                      -0.132                      -0.077
# 2  FLQS22W2GRWQ____                       0.072                       0.072
# 3  FLQS23HTGRWQ____                      -0.278                      -0.208
# 4  FLQS235WGRX5____                       0.217                       0.223
#
#    Distance_X_LOGO_3  Distance_X_LOGO_4  Distance_X_LOGO_5  Distance_X_LOGO_6  \
# 0             -0.027             -0.031             -0.029             -0.001
# 1             -0.081             -0.046             -0.033             -0.062
# 2              0.080              0.068              0.072              0.068
# 3             -0.278             -0.278             -0.278             -0.278
# 4              0.228              0.184              0.218              0.220
#
# ...

# %%
import os
dirlist = os.listdir("./tear")

# %%
dirlist
# Out:
# ['.DS_Store',
#  'diffN66_LD_Camera_RU.csv',
#  'diffN66_LD_Earphone_LD.csv',
#  'diffN66_LD_MainBoard_LU.csv',
#  'diffN66_LU_MainBoard_Sim.csv',
#  'diffN66_LU_Motor_RU.csv',
#  'diffN66_LU_Voice_RU.csv',
#  'newN66_LD_Camera_RU.csv',
#  'newN66_LD_Earphone_LD.csv',
#  'newN66_LD_MainBoard_LU.csv',
#  'newN66_LU_MainBoard_Sim.csv',
#  'newN66_LU_Motor_RU.csv',
#  'newN66_LU_Voice_RU.csv',
#  'returnN66_LD_Camera_RU.csv',
#  'returnN66_LD_Earphone_LD.csv',
#  'returnN66_LD_MainBoard_LU.csv',
#  'returnN66_LU_MainBoard_Sim.csv',
#  'returnN66_LU_Motor_RU.csv',
#  'returnN66_LU_Voice_RU.csv',
#  '\xe5\x87\xba\xe5\x8e\x82\xe5\xad\x98\xe5\x82\xa8N66_LD_Camera_RU.xls',
#  '\xe5\x87\xba\xe5\x8e\x82\xe5\xad\x98\xe5\x82\xa8N66_LD_Earphone_LD.xls',
#  '\xe5\x87\xba\xe5\x8e\x82\xe5\xad\x98\xe5\x82\xa8N66_LD_MainBoard_LU.xls',
#  '\xe5\x87\xba\xe5\x8e\x82\xe5\xad\x98\xe5\x82\xa8N66_LU_MainBoard_Sim.xls',
#  '\xe5\x87\xba\xe5\x8e\x82\xe5\xad\x98\xe5\x82\xa8N66_LU_Motor_RU.xls',
# ...

# %%
import os

# %%
dfList = []
for excelfile in dirlist:
    if os.path.splitext(excelfile)[1] == '.csv':
        print excelfile
        path = './tear/' + excelfile
        dfList.append((pd.read_csv(path, sep=';'), excelfile))
# Out:
# diffN66_LD_Camera_RU.csv
# diffN66_LD_Earphone_LD.csv
# diffN66_LD_MainBoard_LU.csv
# diffN66_LU_MainBoard_Sim.csv
# diffN66_LU_Motor_RU.csv
# diffN66_LU_Voice_RU.csv
# newN66_LD_Camera_RU.csv
# newN66_LD_Earphone_LD.csv
# newN66_LD_MainBoard_LU.csv
# newN66_LU_MainBoard_Sim.csv
# newN66_LU_Motor_RU.csv
# newN66_LU_Voice_RU.csv
# returnN66_LD_Camera_RU.csv
# returnN66_LD_Earphone_LD.csv
# returnN66_LD_MainBoard_LU.csv
# returnN66_LU_MainBoard_Sim.csv
# returnN66_LU_Motor_RU.csv
# returnN66_LU_Voice_RU.csv

# %%
def separateDf(df):

# %%
dfList[0][0].iloc[:, 1:33]
# Out:
#    Distance_X_LOGO_Camera_RU1  Distance_X_LOGO_Camera_RU2  Distance_X_LOGO_3  \
# 0                      -0.036                      -0.031             -0.027
# 1                      -0.132                      -0.077             -0.081
# 2                       0.072                       0.072              0.080
# 3                      -0.278                      -0.208             -0.278
# 4                       0.217                       0.223              0.228
#
#    Distance_X_LOGO_4  Distance_X_LOGO_5  Distance_X_LOGO_6  Distance_X_LOGO_7  \
# 0             -0.031             -0.029             -0.001             -0.030
# 1             -0.046             -0.033             -0.062             -0.083
# 2              0.068              0.072              0.068              0.066
# 3             -0.278             -0.278             -0.278             -0.278
# 4              0.184              0.218              0.220              0.216
#
# ...

# %%
dfList[0][0].iloc[:, 34:67]

# %%
dfList[0][0]
# Out:
#                  SN  Distance_X_LOGO_Camera_RU1  Distance_X_LOGO_Camera_RU2  \
# 0  FLQS20U5GRX2____                      -0.036                      -0.031
# 1  FLQS21TBGRWM____                      -0.132                      -0.077
# 2  FLQS22W2GRWQ____                       0.072                       0.072
# 3  FLQS23HTGRWQ____                      -0.278                      -0.208
# 4  FLQS235WGRX5____                       0.217                       0.223
#
#    Distance_X_LOGO_3  Distance_X_LOGO_4  Distance_X_LOGO_5  Distance_X_LOGO_6  \
# 0             -0.027             -0.031             -0.029             -0.001
# 1             -0.081             -0.046             -0.033             -0.062
# 2              0.080              0.068              0.072              0.068
# 3             -0.278             -0.278             -0.278             -0.278
# 4              0.228              0.184              0.218              0.220
#
# ...

# %%
dfList[0][1]
# Out:
# 'diffN66_LD_Camera_RU.csv'

# %%
dfList[1][0]
# Out:
#                  SN  Distance_X_LOGO_Earphone_LD1  \
# 0  FLQS20U5GRX2____                        -0.030
# 1  FLQS21TBGRWM____                        -0.093
# 2  FLQS22W2GRWQ____                         0.085
# 3  FLQS23HTGRWQ____                        -0.299
# 4  FLQS235WGRX5____                         0.144
#
#    Distance_X_LOGO_Earphone_LD2  Distance_X_LOGO_Earphone_LD3  \
# 0                        -0.034                        -0.034
# 1                        -0.166                        -0.131
# 2                         0.083                         0.085
# 3                        -0.296                        -0.296
# 4                         0.166                         0.200
#
#    Distance_X_LOGO_4  Distance_X_LOGO_5  Distance_X_LOGO_6  Distance_X_LOGO_7  \
# 0             -0.033              0.003              0.000             -0.034
# 1             -0.116             -0.117             -0.127             -0.118
# ...

# %%
dfList[1][1]
# Out:
# 'diffN66_LD_Earphone_LD.csv'

# %%
dfList[1]
# Out:
#                  SN  Distance_X_LOGO_Earphone_LD1  \
# 0  FLQS20U5GRX2____                        -0.030
# 1  FLQS21TBGRWM____                        -0.093
# 2  FLQS22W2GRWQ____                         0.085
# 3  FLQS23HTGRWQ____                        -0.299
# 4  FLQS235WGRX5____                         0.144
#
#    Distance_X_LOGO_Earphone_LD2  Distance_X_LOGO_Earphone_LD3  \
# 0                        -0.034                        -0.034
# 1                        -0.166                        -0.131
# 2                         0.083                         0.085
# 3                        -0.296                        -0.296
# 4                         0.166                         0.200
#
#    Distance_X_LOGO_4  Distance_X_LOGO_5  Distance_X_LOGO_6  Distance_X_LOGO_7  \
# 0             -0.033              0.003              0.000             -0.034
# 1             -0.116             -0.117             -0.127             -0.118
# ...

# %%
dfList[3]
# Out:
#                  SN  Distance_X_LOGO_MainBoard_Sim1  \
# 0  FLQS20U5GRX2____                           0.120
# 1  FLQS21TBGRWM____                          -0.118
# 2  FLQS22W2GRWQ____                          -0.071
# 3  FLQS23HTGRWQ____                           0.001
# 4  FLQS235WGRX5____                           0.026
#
#    Distance_X_LOGO_MainBoard_Sim2  Distance_X_LOGO_3  Distance_X_LOGO_4  \
# 0                           0.062              0.090              0.075
# 1                          -0.048             -0.118             -0.118
# 2                          -0.004             -0.074             -0.080
# 3                           0.060             -0.010              0.030
# 4                           0.070              0.070              0.000
#
#    Distance_X_LOGO_5  Distance_X_LOGO_6  Distance_X_LOGO_7  Distance_X_LOGO_8  \
# 0              0.062              0.150              0.132              0.063
# ...

# %%
dfList[0][1]
# Out:
# 'diffN66_LD_Camera_RU.csv'

# %%
test = dfList[0][0]

# %%
len(dfList)
# Out:
# 18

# %%
test.iloc[:,0:1]
# Out:
#                  SN
# 0  FLQS20U5GRX2____
# 1  FLQS21TBGRWM____
# 2  FLQS22W2GRWQ____
# 3  FLQS23HTGRWQ____
# 4  FLQS235WGRX5____

# %%
def csvToDf(path):
    # import os
    dirlist = os.listdir(path)
    dfList = []
    for excelfile in dirlist:
        if os.path.splitext(excelfile)[1] == '.csv':
            print excelfile
            path = './tear/' + excelfile
            dfList.append((pd.read_csv(path, sep=';'), excelfile))
    return dfList

# %%
csv
