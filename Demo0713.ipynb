# %%
from Transform import combine_df
# Out:
# /Users/hadoop1/anaconda/lib/python2.7/site-packages/pandas/computation/__init__.py:19: UserWarning: The installed version of numexpr 2.4.4 is not supported in pandas and will be not be used
#
#   UserWarning)

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
tearDf = combine_df('./data/tear20/', tag='tear')

# %%
import matplotlib

# %%
from Plot import plot_all_box

# %%
componentList = [x for x in tearDf['component'].value_counts().index]

# %%
from bokeh.io import output_notebook

# %%
import pandas as pd

# %%
output_notebook()
# Out:
#
# <script type="text/javascript">
#     /* BEGIN /Users/hadoop1/anaconda/lib/python2.7/site-packages/bokeh/server/static/js/bokeh.min.js */
# ...

# %%
from Utility import xlsToCsv

# %%
duplicateDf = combine_df('./data/duplicate88/', tag='duplicate')

# %%
len(duplicateDf['SN'].value_counts())
# Out:
# 88

# %%
from Transform import addZDf

# %%
duplicateZDf = addZDf(duplicateDf)

# %%
tearZDf = addZDf(tearDf)

# %%
dropDf = combine_df('./data/drop5/', tag='drop')

# %%
dropZDf = addZDf(dropDf)

# %%
import pandas as pd

# %%
allDf = pd.concat([dropZDf, duplicateZDf, tearZDf])

# %%
allDf
# Out:
#               SN            component condition metric status    value1  \
# 0   FLQS11MXGRWQ      LD_Battery_Left      drop      x   diff -0.251000
# 1   FLQS11WBGRWQ      LD_Battery_Left      drop      x   diff  0.940000
# 2   FLQS11X1GRWQ      LD_Battery_Left      drop      x   diff  0.011000
# 3   FLQS13MEGRWQ      LD_Battery_Left      drop      x   diff -0.551000
# 4   FLQS138GGRWQ      LD_Battery_Left      drop      x   diff -0.340000
# 0   FLQS11MXGRWQ      LD_Battery_Left      drop      y   diff -0.283125
# 1   FLQS11WBGRWQ      LD_Battery_Left      drop      y   diff  0.863781
# 2   FLQS11X1GRWQ      LD_Battery_Left      drop      y   diff  0.091125
# 3   FLQS13MEGRWQ      LD_Battery_Left      drop      y   diff -0.430375
# 4   FLQS138GGRWQ      LD_Battery_Left      drop      y   diff -0.234094
# 0   FLQS11MXGRWQ      LD_Battery_Left      drop  theta   diff -0.325000
# 1   FLQS11WBGRWQ      LD_Battery_Left      drop  theta   diff  0.878000
# ...

# %%
allDf['condition'].value_counts()
# Out:
# duplicate    10560
# tear          2400
# drop           595
# Name: condition, dtype: int64

# %%
from Transform import create_ML_df

# %%
mlDf = create_ML_df(allDf)

# %%
mlDf.isnull().sum().value_counts()
# Out:
# 0     116
# 32      5
# dtype: int64

# %%
mlDf = mlDf[~mlDf.index.str.contains('FLQS3047GRWM')]

# %%
from Model import train_test_split

# %%
trainDf, testDf = train_test_split(df=mlDf)

# %%
trainDf.shape
# Out:
# (2144, 121)

# %%
testDf.shape
# Out:
# (1440, 121)

# %%
X, y = mlDf.iloc[:,0:-1], mlDf.iloc[:,-1]

# %%
from Model import logisticModeling

# %%
model, (y_test, y_predict) = logisticModeling(trainDf, testDf)
# Out:
# /Users/hadoop1/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1074: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
from sklearn.metrics import classification_report

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
print classification_report(y_test, y_predict)
# Out:
#              precision    recall  f1-score   support
#
#        drop       0.06      0.02      0.03        64
#   duplicate       0.93      0.99      0.96      1120
#        tear       0.79      0.73      0.76       256
#
# avg / total       0.87      0.90      0.88      1440

# %%
cmLogistic = confusion_matrix(y_test, y_predict)

# %%
from Plot import plot_confusion_matrix

# %%
cmRecall = cmLogistic.astype(float) / cmLogistic.sum(axis=1)

# %%
cmPrecision = cmLogistic.astype(float) / cmLogistic.sum(axis=0)

# %%
cmF = (cmRecall * cmPrecision * 2) / (cmRecall + cmPrecision)

# %%
np.around(cmF, 2)
# Out:
# array([[ 0.02,  0.02,  0.14],
#        [  nan,  0.96,  0.06],
#        [ 0.38,  0.05,  0.76]])

# %%
cmLogistic.sum(axis=0)
# Out:
# array([  16, 1186,  238])

# %%
print(cmLogistic)
plot_confusion_matrix(y_test, y_predict)
# Out:
# [[   1   28   35]
#  [   0 1104   16]
#  [  15   54  187]]
# /Users/hadoop1/anaconda/lib/python2.7/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %%
import pickle

# %%
fdump = open('./model/logistic0715', 'wb')
pickle.dump(model, fdump)

# %%
fdump.close()

# %%
model
# Out:
# GridSearchCV(cv=None, error_score='raise',
#        estimator=Pipeline(steps=[('imputer', Imputer(axis=1, copy=True, missing_values='NaN', strategy='median', verbose=0)), ('scaler', RobustScaler(copy=True, with_centering=True, with_scaling=True)), ('clf', LogisticRegression(C=1.0, class_weight='balanced', dual=False,
#           fit_intercept=True, intercept_scaling=1, max_iter=1000,
#           multi_class='ovr', n_jobs=1, penalty='l2', random_state=None,
#           solver='liblinear', tol=0.0001, verbose=0, warm_start=False))]),
#        fit_params={}, iid=True, n_jobs=1,
#        param_grid={'clf__C': (10, 5, 1, 0.1, 0.01, 0.001, 0.0001), 'clf__penalty': ('l1', 'l2'), 'clf__tol': (1, 0.1, 0.01, 0.001, 0.0001)},
#        pre_dispatch='2*n_jobs', refit=True, scoring='f1_weighted',
#        verbose=0)

# %%
bestModel = model.best_estimator_.named_steps['clf']

# %%
model.best_params_
# Out:
# {'clf__C': 0.01, 'clf__penalty': 'l1', 'clf__tol': 0.01}

# %%
bestModel.coef_
# Out:
# array([[  0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   2.54062991e-01,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           1.96834798e-02,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,  -5.36586439e-02,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,  -7.45426554e-01,   0.00000000e+00,
# ...

# %%
from Model import SVMModeling

# %%
modelSVM, (y_test, y_predict) = SVMModeling(trainDf, testDf)

# %%
print classification_report(y_test, y_predict)
# Out:
#              precision    recall  f1-score   support
#
#        drop       0.03      0.03      0.03        64
#   duplicate       0.91      0.91      0.91      1120
#        tear       0.65      0.62      0.64       256
#
# avg / total       0.82      0.82      0.82      1440

# %%
cmSVM = confusion_matrix(y_test, y_predict)

# %%
print(cmSVM)
plot_confusion_matrix(y_test, y_predict)
# Out:
# [[   2   42   20]
#  [  32 1023   65]
#  [  32   64  160]]

# %%
from Model import DTModeling

# %%
modelDT, (y_test, y_predict) = DTModeling(trainDf, testDf)

# %%
print classification_report(y_test, y_predict)
# Out:
#              precision    recall  f1-score   support
#
#        drop       0.00      0.00      0.00        64
#   duplicate       0.87      0.91      0.89      1120
#        tear       0.43      0.26      0.33       256
#
# avg / total       0.75      0.75      0.75      1440

# %%
cm = confusion_matrix(y_test, y_predict)

# %%
print(cm)
plot_confusion_matrix(y_test, y_predict)
# Out:
# [[   0   48   16]
#  [  32 1015   73]
#  [  88  101   67]]

# %%
from IPython.display import Image

# %%
from sklearn import tree

# %%
bestTreeModel = modelDT.best_estimator_.named_steps['clf']

# %%
tree.export_graphviz(bestTreeModel, out_file='tree.dot')
# !dot -Tpng tree.dot -o tree.png
Image(filename='tree.png')

# %%
componentList
# Out:
# ['LD_Battery_Up',
#  'LU_Voice_LD',
#  'LU_Button_LD',
#  'LU_MainBoard_Sim',
#  'LD_Front_Camera_LD',
#  'LU_MainBoard_RD',
#  'LD_Camera_LD',
#  'LD_NFC_Up',
#  'LU_Button_RU',
#  'LD_Battery_Left',
#  'LU_Motor_RU',
#  'LD_MainBoard_LU',
#  'LD_Front_Camera_RU',
#  'LU_Voice_RU',
#  'LD_NFC_Down',
#  'LD_Camera_RU',
#  'LD_MainBoard_RU',
#  'LU_Battery_Right',
#  'LD_Earphone_RU',
#  'LD_MainBoard_Corner',
#  'LU_MainBoard_LD',
#  'LU_Battery_Down',
#  'LD_Earphone_LD',
#  'LU_Motor_LD']

# %%
from Plot import plot_all_box
