# %%
from Transform import createQueryDf
# Out:
# /Users/hadoop1/anaconda/lib/python2.7/site-packages/pandas/computation/__init__.py:19: UserWarning: The installed version of numexpr 2.4.4 is not supported in pandas and will be not be used
#
#   UserWarning)

# %%
from Utility import xlsToCsv

# %%
xlsToCsv('./data/20new/')

# %%
tearQueryMlDf = createQueryDf('./data/20new/')

# %%
tearQueryMlDf
# Out:
# comp_metric       LD_Battery_Left_x  LD_Battery_Left_y  LD_Battery_Left_theta  \
# FLNS31Y0GRX5_avg          -0.041437          -0.291094              -0.095187
# FLNS32DNGRX5_avg          -0.533281          -0.717375               0.418281
# FLNS32G4GRX5_avg          -0.146562          -0.497750               0.268688
# FLQS300WGRX8_avg           0.044312          -0.525906              -0.287406
# FLQS3023GRX8_avg           0.369437           0.322781              -0.188875
# FLQS302CGRX8_avg           0.000000           0.000000               0.000000
# FLQS304AGRX8_avg           0.114344           0.396594               0.049531
# FLQS304UGRX2_avg          -0.417844           0.766687               0.186500
# FLQS3075GRX8_avg           0.408469          -0.249031              -0.200562
# FLQS3089GRXL_avg          -0.155406          -0.170812              -0.022250
# FLQS30BYGRX8_avg          -0.445844           0.077875               0.123344
# ...

# %%
import pickle

# %%
fileLoad = open('./model/logistic0715', 'rb')
model = pickle.load(fileLoad)

# %%
fileLoad.close()

# %%
fileLoad = open('./col.dump', 'rb')
column = pickle.load(fileLoad)

# %%
predict = model.predict(tearQueryMlDf[column].iloc[:, 0:-1])

# %%
import pandas as pd

# %%
pd.Series(predict).value_counts()
# Out:
# tear         13
# duplicate     4
# drop          3
# dtype: int64

# %%
13.0/20
# Out:
# 0.65

# %%
model.predict_proba(tearQueryMlDf[column].iloc[:, 0:-1])[:,2]
# Out:
# array([ 0.69851502,  0.54010299,  0.71717407,  0.81756121,  0.95909106,
#         0.05354768,  0.39234948,  0.91023063,  0.79667489,  0.17675915,
#         0.77338545,  0.16245004,  0.76785589,  0.29389965,  0.95482705,
#         0.20116598,  0.49551777,  0.4803276 ,  0.98529385,  0.39388963])

# %%
model.predict_proba(tearQueryMlDf[column].iloc[:, 0:-1])[:,0]
# Out:
# array([ 0.14817396,  0.45169837,  0.12644635,  0.08401151,  0.00154785,
#         0.12915884,  0.03488094,  0.06510401,  0.04908188,  0.22621604,
#         0.0567666 ,  0.72442847,  0.13567171,  0.55888245,  0.03644377,
#         0.23603976,  0.46158243,  0.43713681,  0.01433592,  0.57921132])

# %%
model.predict_proba(tearQueryMlDf[column].iloc[:, 0:-1])[:,1]
# Out:
# array([  1.53311021e-01,   8.19864197e-03,   1.56379578e-01,
#          9.84272720e-02,   3.93610874e-02,   8.17293477e-01,
#          5.72769578e-01,   2.46653615e-02,   1.54243238e-01,
#          5.97024807e-01,   1.69847949e-01,   1.13121487e-01,
#          9.64723981e-02,   1.47217903e-01,   8.72917689e-03,
#          5.62794258e-01,   4.28998059e-02,   8.25355821e-02,
#          3.70224383e-04,   2.68990426e-02])

# %%
predict
# Out:
# array(['tear', 'tear', 'tear', 'tear', 'tear', 'duplicate', 'duplicate',
#        'tear', 'tear', 'duplicate', 'tear', 'drop', 'tear', 'drop', 'tear',
#        'duplicate', 'tear', 'tear', 'tear', 'drop'], dtype=object)

# %%
testQuerySN = [x for x in tearQueryMlDf.index]

# %%
testQuerySN
# Out:
# ['FLNS31Y0GRX5_avg',
#  'FLNS32DNGRX5_avg',
#  'FLNS32G4GRX5_avg',
#  'FLQS300WGRX8_avg',
#  'FLQS3023GRX8_avg',
#  'FLQS302CGRX8_avg',
#  'FLQS304AGRX8_avg',
#  'FLQS304UGRX2_avg',
#  'FLQS3075GRX8_avg',
#  'FLQS3089GRXL_avg',
#  'FLQS30BYGRX8_avg',
#  'FLQS30DLGRXL_avg',
#  'FLQS30GVGRX8_avg',
#  'FLQS30KBGRX8_avg',
#  'FLQS30LUGRXL_avg',
#  'FLQS31B0GRX2_avg',
#  'FLQS31B2GRWM_avg',
#  'FLQS31K2GRWM_avg',
#  'FLQS31QAGRX2_avg',
#  'FLQS32CMGRWM_avg']

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
model.predict_proba(tearQueryMlDf.iloc[:,0:-1])[:,2]
# Out:
# array([ 0.0739948 ,  0.01837327,  0.03582035,  0.00868885,  0.00067063,
#         0.05354768,  0.04550668,  0.07034046,  0.01322352,  0.08318471,
#         0.07287401,  0.02564108,  0.1806786 ,  0.03032283,  0.03044903,
#         0.04491505,  0.00626954,  0.02369459,  0.00445605,  0.05896151])

# %%
plt.style.use('ggplot')

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from sklearn.metrics import accuracy_score
def predict_query(mlDf, model, column):
    '''predict query according to specified model
    
    Notes:
    
    Argus:
    
    Return:
    
    '''
    predict = model.predict(mlDf[column].iloc[:,0:-1])
    predict_prob = model.predict_proba(mlDf[column].iloc[:,0:-1])
    
    accuracy = accuracy_score(mlDf[column].iloc[:,-1], predict)
    
    print accuracy
    plot_tear_probability(mlDf, predict_prob)

# %%
predict_query(test20, model, column)
# Out:
# 0.8

# %%
predict_prob = model.predict_proba(test20[column].iloc[:,0:-1])

# %%
import re

# %%
re.

# %%
[x.replace('_avg', '') for x in test20.index]
# Out:
# ['FLNS2009GRWF',
#  'FLNS202VGRWV',
#  'FLQS2137GRWV',
#  'FLQS2168GRWV',
#  'FLQS2238GRWM',
#  'FLQS23VUGRX2',
#  'FLQS2C39GRX5',
#  'FLQS2C44GRX5',
#  'FLQS2CBBGRX5',
#  'FLQS300JGRWM',
#  'FLQS303AGRWY',
#  'FLQS303SGRWY',
#  'FLQS304WGRWQ',
#  'FLQS30BLGRWY',
#  'FLQS30DEGRWY',
#  'FLQS30LQGRWY',
#  'FLQS30SPGRWY',
#  'FLQS30W7GRWY',
#  'FLQS3137GRWY',
#  'FLQS314MGRWY']

# %%
import numpy as np
def plot_probability(mlDf, predict_prob):
    
    N = len(predict_prob)
    ind = np.arange(N)
    width = 0.3
    
    probaDrop = predict_prob[:,0]
    probaDup = predict_prob[:,1]
    probaTear = predict_prob[:,2]
    
    fig, ax = plt.subplots(figsize=(20,8))
    
    rects1 = ax.bar(ind, probaDup, width, color='g', alpha=0.6)
    rects2 = ax.bar(ind+width, probaDrop, width, color='b', alpha=0.6)
    rects3 = ax.bar(ind+width+width, probaTear, width, color='r', alpha=0.6)
    
    # add some text for labels, title and axes ticks
    ax.set_ylabel('Probability', fontsize=20)
    ax.set_title('Probability by cases', fontsize=20)
    ax.set_xticks(ind + width + width)
    ax.set_xticklabels([x.replace('_avg', '') for x in mlDf.index], fontsize=20)
    
    ax.legend((rects1[0], rects2[0], rects3[0]), ('Normal', 'Drop', 'Tear'), fontsize=20)
    
    plt.xticks(rotation='vertical')
    # plt.figure(figsize=(10,5))
    plt.show()

# %%
plot_probability(test20, predict_prob)

# %%
plt.bar?

# %%
def plot_tear_probability(mlDf, predict_prob):
    '''
    '''
    testQuerySN = mlDf.index
    plt.xticks(range(len(testQuerySN)), testQuerySN, rotation='vertical')
    plt.bar(range(len(predict_prob[:,2])), predict_prob[:,2])

# %%
model.predict_proba(test20[column].iloc[:,0:-1])[:,2]
# Out:
# array([ 0.70380704,  0.37091783,  0.98943873,  0.8426225 ,  0.96757015,
#         0.49223082,  0.87215389,  0.91042896,  0.99401655,  0.99151408,
#         0.89269906,  0.55082772,  0.14151087,  0.69260367,  0.521344  ,
#         0.15435215,  0.74822495,  0.59796763,  0.7865953 ,  0.0913813 ])

# %%
plot_probability(test20, model.predict_proba(test20[column].iloc[:,0:-1])[:,2])

# %%
plt.xticks(range(len(testQuerySN)), testQuerySN, rotation='vertical')
plt.bar(range(len(model.predict_proba(tearQueryMlDf[column].iloc[:,0:-1])[:,2])), model.predict_proba(tearQueryMlDf[column].iloc[:,0:-1])[:,2])
# Out:
# <Container object of 20 artists>

# %%
model.fit?

# %%
test20 = createQueryDf('./data/tear20/')

# %%
model.predict(test20[column].iloc[:,0:-1])
# Out:
# array(['tear', 'duplicate', 'tear', 'tear', 'tear', 'tear', 'tear', 'tear',
#        'tear', 'tear', 'tear', 'tear', 'duplicate', 'tear', 'tear',
#        'duplicate', 'tear', 'tear', 'tear', 'duplicate'], dtype=object)

# %%
dropTest20 = createQueryDf('./data/ok与摔1   20张图/')

# %%
dropTest20['label'] = 'drop'

# %%
model.predict(dropTest20[column].iloc[:,0:-1])
# Out:
# array(['tear', 'tear', 'tear', 'tear', 'tear', 'tear', 'tear', 'tear',
#        'tear', 'tear', 'tear', 'tear', 'tear', 'tear', 'tear', 'tear',
#        'tear', 'tear', 'tear', 'tear'], dtype=object)

# %%
dropTest20.columns.str.contains('_z')
# Out:
# array([False, False, False, False,  True, False, False, False, False,
#         True, False, False, False, False,  True, False, False, False,
#        False,  True, False, False, False, False,  True, False, False,
#        False, False,  True, False, False, False, False,  True, False,
#        False, False, False,  True, False, False, False, False,  True,
#        False, False, False, False,  True, False, False, False, False,
#         True, False, False, False, False,  True, False, False, False,
#        False,  True, False, False, False, False,  True, False, False,
#        False, False,  True, False, False, False, False,  True, False,
#        False, False, False,  True, False, False, False, False,  True,
#        False, False, False, False,  True, False, False, False, False,
#         True, False, False, False, False,  True, False, False, False,
#        False,  True, False, False, False, False,  True, False, False,
#        False, False,  True, False], dtype=bool)

# %%
dropTest20

# %%
dropTest20.iloc[:,dropTest20.columns.str.contains('_z')]
# Out:
#                   LD_Battery_Left_z  LD_Battery_Up_z  LD_Camera_LD_z  \
# F2LS30UNGRX8_avg           0.000000         0.000000        0.000000
# F2LS339XHFM1_avg           0.327312         0.207900        0.411193
# F2LS35BZHFM1_avg           0.167325         0.278686        0.470290
# F2LS38TUGRXL_avg           0.241019         0.201165        0.400640
# F2LS38VQGRXL_avg           0.182579         0.280707        0.209246
# F2LS3957GRXL_avg           0.447303         0.417219        0.102297
# F2LS39Q6GRXL_avg           0.277477         0.091131        0.090378
# F2LS3A7AHFM2_avg           0.637609         0.577982        0.756772
# F2LS3A8AGRXL_avg           0.118491         0.144030        0.180212
# F2LS3BDVGRXL_avg           0.231805         0.308442        0.047628
# F2LS3EKPHFM2_avg           0.298151         0.230780        0.181087
# F2LS3HFBHFM5_avg           0.513974         0.440787        0.088824
# F2LS3HFRHFM5_avg           0.493695         0.505451        0.160160
# ...

# %%
predict_query(dropTest20, model, column)
# Out:
# 0.0

# %%
from Plot import plot_all_box

# %%
from Transform import combine_df

# %%
dropOriDf = combine_df('./data/ok与摔1   20张图/', tag='drop')

# %%
componentList = [x for x in dropOriDf['component'].value_counts().index]

# %%
from Plot import plot_box

# %%
tearOri20Df = combine_df('./data/tear20/', tag='tear')

# %%
from Transform import addZDf

# %%
tearOri20ZDf = addZDf(tearOri20Df)

# %%
componentSig = ['LU_Battery_Down','LU_Voice_LD', 'LU_Motor_RU', 'LU_Battery_Right', 'LU_Battery_Right', 'LU_MainBoard_LD']

# %%
metricSig = ['z', 'z', 'y', 'y', 'x', 'theta']

# %%
tearOri20ZDf
# Out:
#               SN            component condition metric status    value1  \
# 0   FLNS202VGRWV      LD_Battery_Left      tear      x  diff1  0.091000
# 1   FLNS2009GRWF      LD_Battery_Left      tear      x  diff1  0.142000
# 2   FLQS2C39GRX5      LD_Battery_Left      tear      x  diff1  0.128000
# 3   FLQS2C44GRX5      LD_Battery_Left      tear      x  diff1  0.154000
# 4   FLQS2CBBGRX5      LD_Battery_Left      tear      x  diff1  0.341000
# 5   FLQS23VUGRX2      LD_Battery_Left      tear      x  diff1 -0.331000
# 6   FLQS30BLGRWY      LD_Battery_Left      tear      x  diff1 -0.515000
# 7   FLQS30DEGRWY      LD_Battery_Left      tear      x  diff1  0.130000
# 8   FLQS30LQGRWY      LD_Battery_Left      tear      x  diff1 -0.006000
# 9   FLQS30SPGRWY      LD_Battery_Left      tear      x  diff1  0.415000
# 10  FLQS30W7GRWY      LD_Battery_Left      tear      x  diff1  0.180000
# 11  FLQS300JGRWM      LD_Battery_Left      tear      x  diff1  0.611000
# ...

# %%
tearOri20ZDf
# Out:
#               SN            component condition metric status    value1  \
# 0   FLNS202VGRWV      LD_Battery_Left      tear      x  diff1  0.091000
# 1   FLNS2009GRWF      LD_Battery_Left      tear      x  diff1  0.142000
# 2   FLQS2C39GRX5      LD_Battery_Left      tear      x  diff1  0.128000
# 3   FLQS2C44GRX5      LD_Battery_Left      tear      x  diff1  0.154000
# 4   FLQS2CBBGRX5      LD_Battery_Left      tear      x  diff1  0.341000
# 5   FLQS23VUGRX2      LD_Battery_Left      tear      x  diff1 -0.331000
# 6   FLQS30BLGRWY      LD_Battery_Left      tear      x  diff1 -0.515000
# 7   FLQS30DEGRWY      LD_Battery_Left      tear      x  diff1  0.130000
# 8   FLQS30LQGRWY      LD_Battery_Left      tear      x  diff1 -0.006000
# 9   FLQS30SPGRWY      LD_Battery_Left      tear      x  diff1  0.415000
# 10  FLQS30W7GRWY      LD_Battery_Left      tear      x  diff1  0.180000
# 11  FLQS300JGRWM      LD_Battery_Left      tear      x  diff1  0.611000
# ...

# %%
for item in zip(componentSig, metricSig):
    plot_all_box(tearOri20ZDf, component=item[0], labelList=['SN'], metric=item[1])
# Out:
# <script type="text/javascript">
#         Bokeh.$(function() {
# ...

# %%
# %matplotlib inline

# %%
from bokeh.io import output_notebook
output_notebook()
# Out:
#
# <script type="text/javascript">
#     /* BEGIN /Users/hadoop1/anaconda/lib/python2.7/site-packages/bokeh/server/static/js/bokeh.min.js */
# ...

# %%
plot_all_box(tearOri20ZDf, component=componentSig[1], labelList=['SN'], metric='z')

# %%
plot_all_box(tearOri20ZDf, component=componentSig[1], labelList=['SN'], metric='z')
# Out:
# <script type="text/javascript">
#         Bokeh.$(function() {
# ...

# %%
metrics = [metric for metric in tearOri20Df['metric'].value_counts().index]

# %%
conditions = [condition for condition in tearOri20Df['condition'].value_counts().index]

# %%
dfComp=tearOri20Df[tearOri20Df['component'] == componentList[0]]

# %%
from Transform import lineup

# %%
frames = [lineup(dfComp[(dfComp['metric'] == metric) & (dfComp['condition'] == condition)], metric=metric, condition=condition)\
        for condition in conditions for metric in metrics]

# %%
xyztDf = pd.concat(frames)

# %%
xyztDfFiltered = xyztDf[xyztDf['metric'] == 'z']

# %%
xyztDf['metric'].value_counts()
# Out:
# y           640
# theta       640
# x           640
# thetaAbs    640
# Name: metric, dtype: int64

# %%
from bokeh.charts import BoxPlot, show

# %%
xyztDfFiltered
# Out:
# Empty DataFrame
# Columns: [value, SN, metric, condition]
# Index: []
