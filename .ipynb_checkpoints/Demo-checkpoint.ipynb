# %%
from Transform import combine_df
# Out:
# /Users/hadoop1/anaconda/lib/python2.7/site-packages/pandas/computation/__init__.py:19: UserWarning: The installed version of numexpr 2.4.4 is not supported in pandas and will be not be used
#
#   UserWarning)

# %%
dropDf = combine_df('./dropAll/', tag='drop')

# %%
tearDf = combine_df('./tearAll/', tag='tear')

# %%
duplicateDf = combine_df('./duplicateAll/', tag='duplicate')

# %%
from Transform import create_zDf

# %%
frames = [dropDf, tearDf, duplicateDf]

# %%
import pandas as pd

# %%
xytDf = pd.concat(frames)

# %%
zDf = create_zDf(xytDf)

# %%
frames = [xytDf, zDf]
allDf = pd.concat(frames)

# %%
allDf
# Out:
#               SN            component  condition metric status    value1  \
# 0   FLQS11MXGRWQ      LD_Battery_Left       drop      x   diff -0.251000
# 1   FLQS11WBGRWQ      LD_Battery_Left       drop      x   diff  0.940000
# 2   FLQS11X1GRWQ      LD_Battery_Left       drop      x   diff  0.011000
# 3   FLQS13MEGRWQ      LD_Battery_Left       drop      x   diff -0.551000
# 4   FLQS138GGRWQ      LD_Battery_Left       drop      x   diff -0.340000
# 0   FLQS11MXGRWQ      LD_Battery_Left       drop      y   diff -0.283125
# 1   FLQS11WBGRWQ      LD_Battery_Left       drop      y   diff  0.863781
# 2   FLQS11X1GRWQ      LD_Battery_Left       drop      y   diff  0.091125
# 3   FLQS13MEGRWQ      LD_Battery_Left       drop      y   diff -0.430375
# 4   FLQS138GGRWQ      LD_Battery_Left       drop      y   diff -0.234094
# 0   FLQS11MXGRWQ      LD_Battery_Left       drop  theta   diff -0.325000
# 1   FLQS11WBGRWQ      LD_Battery_Left       drop  theta   diff  0.878000
# ...

# %%
from Plot import plot_all_box

# %%
componentList = allDf['component'].value_counts().index

# %%
len(componentList)
# Out:
# 24

# %%
plot_all_box(allDf, component=componentList[0], lableList=['condition'], outliers=False, metric='z')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-5b91fed2de2b> in <module>()
# ----> 1 plot_all_box(allDf, component=componentList[0], lableList=['condition'], outliers=False, metric='z')
#
# TypeError: plot_all_box() takes at least 3 arguments (3 given)

# %%
plot_all_box(allDf, component=componentList[1], outliers=True, labelList=['condition','metric','SN'], metric='z')
# Out:
# /Users/hadoop1/anaconda/lib/python2.7/site-packages/bokeh/charts/_attributes.py:78: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   df = df.sort(columns=columns)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-a53cf36658f0> in <module>()
# ----> 1 plot_all_box(allDf, component=componentList[1], outliers=True, labelList=['condition','metric','SN'], metric='z')
#
# /Users/hadoop1/projects/SUR-Project/Plot.py in plot_all_box(df, component, labelList, outliers, **labelFilter)
#      73     p = BoxPlot(xyztFilteredDf, values='value', label=labelList, color=labelList[0], outliers=outliers, title=component)
#      74     #p.add_tools(HoverTool())
# ---> 75     output_file("condition.html")
#      76     show(p)
#
# NameError: global name 'output_file' is not defined
